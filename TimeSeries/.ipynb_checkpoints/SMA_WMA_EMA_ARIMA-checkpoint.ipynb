# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
plt.style.use('fivethirtyeight')
# Out:
# /tmp/ipykernel_32735/2752778083.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
df = pd.read_csv('TSLA.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-07-23  646.359985  648.799988  637.299988  643.380005  643.380005
# 1  2021-07-26  650.969971  668.200012  647.109985  657.619995  657.619995
# 2  2021-07-27  663.400024  666.500000  627.239990  644.780029  644.780029
# 3  2021-07-28  647.000000  654.969971  639.400024  646.979980  646.979980
# 4  2021-07-29  649.789978  683.690002  648.799988  677.349976  677.349976
#
#      Volume
# 0  14604900
# 1  25336600
# 2  32813300
# 3  16006600
# 4  30394600

# %%
df = df.loc[:,['Date','Close']]
df.head()
# Out:
#          Date       Close
# 0  2021-07-23  643.380005
# 1  2021-07-26  657.619995
# 2  2021-07-27  644.780029
# 3  2021-07-28  646.979980
# 4  2021-07-29  677.349976

# %%
#plot the data
train = df.loc[df['Date'] <= '2021-12-31']
test = df.loc[df['Date'] > '2021-12-31']
test = test.set_index('Date')

test.index = pd.to_datetime(test.index)
test.head()
# Out:
#                   Close
# Date
# 2022-01-03  1199.780029
# 2022-01-04  1149.589966
# 2022-01-05  1088.119995
# 2022-01-06  1064.699951
# 2022-01-07  1026.959961

# %%
#plotting
plt.figure(figsize=(12,6))
plt.plot(test['Close'], label='Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
#Simple Moving Average - Rolling Mean - We can do rolling mean of the number of days - k value
sma10 = df['Close'].rolling(10).mean()
sma2 = df['Close'].rolling(2).mean()
#The above code is for finding 10-days SMA.  This is done on the dataset

df['10-day SMA'] = np.round(sma10,decimals=3)
df['2-day SMA'] = np.round(sma2,decimals=3)
train = df.loc[df['Date'] <= '2021-12-31']
test = df.loc[df['Date'] > '2021-12-31']
test = test.set_index('Date')
test.index = pd.to_datetime(test.index)



plt.figure(figsize=(12,6))
plt.plot(test['Close'], label='Price')
plt.plot(test['10-day SMA'],label='10-day SMA')
plt.plot(test['2-day SMA'],label='2-day SMA')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
df.head(15)
# Out:
#           Date       Close  10-day SMA  2-day SMA
# 0   2021-07-23  643.380005         NaN        NaN
# 1   2021-07-26  657.619995         NaN    650.500
# 2   2021-07-27  644.780029         NaN    651.200
# 3   2021-07-28  646.979980         NaN    645.880
# 4   2021-07-29  677.349976         NaN    662.165
# 5   2021-07-30  687.200012         NaN    682.275
# 6   2021-08-02  709.669983         NaN    698.435
# 7   2021-08-03  709.739990         NaN    709.705
# 8   2021-08-04  710.919983         NaN    710.330
# 9   2021-08-05  714.630005     680.227    712.775
# 10  2021-08-06  699.099976     685.799    706.865
# 11  2021-08-09  713.760010     691.413    706.430
# 12  2021-08-10  709.989990     697.934    711.875
# 13  2021-08-11  707.820007     704.018    708.905
# 14  2021-08-12  722.250000     708.508    715.035

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
df.tail(15)
df.head(15)
# Out:
#           Date       Close  10-day SMA  2-day SMA
# 0   2021-07-23  643.380005         NaN        NaN
# 1   2021-07-26  657.619995         NaN    650.500
# 2   2021-07-27  644.780029         NaN    651.200
# 3   2021-07-28  646.979980         NaN    645.880
# 4   2021-07-29  677.349976         NaN    662.165
# 5   2021-07-30  687.200012         NaN    682.275
# 6   2021-08-02  709.669983         NaN    698.435
# 7   2021-08-03  709.739990         NaN    709.705
# 8   2021-08-04  710.919983         NaN    710.330
# 9   2021-08-05  714.630005     680.227    712.775
# 10  2021-08-06  699.099976     685.799    706.865
# 11  2021-08-09  713.760010     691.413    706.430
# 12  2021-08-10  709.989990     697.934    711.875
# 13  2021-08-11  707.820007     704.018    708.905
# 14  2021-08-12  722.250000     708.508    715.035

# %%
#Laxmi look from here
#Finding the last date for the data available
#last_date = df['Date'].max()
#history = [x for x in df]
predictions = list()
#t = 3

for t in range(len(df)):
    #if (t!=0 && t!=1):
    #    print(df.loc[t+1]['Date'])
    #    print(df.loc[t+1]['2-day SMA'])
    if(t == 0 or t == 1):
        pred_value = np.NaN
    else:
        pred_value = df.loc[t-1]['2-day SMA']
    predictions.append(pred_value)
#Appending predictions to the dataset df
df.loc[:,'2-day Pred'] = predictions
#df.head(15)
df.tail(15)
# Out:
#            Date        Close  10-day SMA  2-day SMA  2-day Pred
# 112  2021-12-31  1056.780029    1024.263   1063.560    1078.265
# 113  2022-01-03  1199.780029    1050.984   1128.280    1063.560
# 114  2022-01-04  1149.589966    1075.949   1174.685    1128.280
# 115  2022-01-05  1088.119995    1090.908   1118.855    1174.685
# 116  2022-01-06  1064.699951    1096.491   1076.410    1118.855
# 117  2022-01-07  1026.959961    1092.487   1045.830    1076.410
# 118  2022-01-10  1058.119995    1088.905   1042.540    1045.830
# 119  2022-01-11  1064.400024    1086.498   1061.260    1042.540
# 120  2022-01-12  1106.219971    1088.501   1085.310    1061.260
# 121  2022-01-13  1031.560059    1084.623   1068.890    1085.310
# 122  2022-01-14  1049.609985    1083.906   1040.585    1068.890
# 123  2022-01-18  1030.510010    1066.979   1040.060    1040.585
# 124  2022-01-19   995.650024    1051.585   1013.080    1040.060
# 125  2022-01-20   996.270020    1042.400    995.960    1013.080
# 126  2022-01-21   943.900024    1030.320    970.085     995.960

# %%
df_new = df

# %%
df_new.tail(10)
# Out:
#            Date        Close  10-day SMA  2-day SMA  2-day Pred
# 117  2022-01-07  1026.959961    1092.487   1045.830    1076.410
# 118  2022-01-10  1058.119995    1088.905   1042.540    1045.830
# 119  2022-01-11  1064.400024    1086.498   1061.260    1042.540
# 120  2022-01-12  1106.219971    1088.501   1085.310    1061.260
# 121  2022-01-13  1031.560059    1084.623   1068.890    1085.310
# 122  2022-01-14  1049.609985    1083.906   1040.585    1068.890
# 123  2022-01-18  1030.510010    1066.979   1040.060    1040.585
# 124  2022-01-19   995.650024    1051.585   1013.080    1040.060
# 125  2022-01-20   996.270020    1042.400    995.960    1013.080
# 126  2022-01-21   943.900024    1030.320    970.085     995.960

# %%
start_date = pd.to_datetime(df['Date'].max())
#print(start_date)
#print(type(start_date))
end_date = start_date + pd.DateOffset(days=7)

#print(type(end_date))
date_list_pred = list()
while start_date <= end_date:
    next_date = start_date + pd.DateOffset(days=1)
    prev_date = start_date + pd.DateOffset(days=-1)
    if not (next_date.weekday()==5 or next_date.weekday()==6):
        #df_new.loc[len(df_new.index)] = [next_date,np.nan,np.nan,np.nan,
        #
        print(df_new.loc[len(df_new.index)-1]['2-day Pred'])
        print(df_new.loc[len(df_new.index)-2]['2-day Pred'])
        sma2_pred = (df_new.loc[len(df_new.index)-1]['2-day Pred'] + df_new.loc[len(df_new.index)-1]['2-day Pred'])/2
        print(sma2_pred)
    start_date = start_date + pd.DateOffset(days=1)
    #df_new.loc[len(df_new.index)] = [next_date,np.nan,np.nan,np.nan,np.nan]    
#df_new.tail(10)
# Out:
# 2022-01-21 00:00:00
# 995.96
# 1013.08
# 995.96
# 995.96
# 1013.08
# 995.96
# 995.96
# 1013.08
# 995.96
# 995.96
# 1013.08
# 995.96
# 995.96
# 1013.08
# 995.96

# %%
# Out:
#           Date Close 10-day SMA 2-day SMA 2-day Pred
# 133 2022-02-05   NaN        NaN       NaN        NaN
# 134 2022-02-06   NaN        NaN       NaN        NaN
# 135 2022-02-07   NaN        NaN       NaN        NaN
# 136 2022-02-08   NaN        NaN       NaN        NaN
# 137 2022-02-09   NaN        NaN       NaN        NaN
# 138 2022-02-10   NaN        NaN       NaN        NaN
# 139 2022-02-11   NaN        NaN       NaN        NaN
# 140 2022-02-12   NaN        NaN       NaN        NaN
# 141 2022-02-13   NaN        NaN       NaN        NaN
# 142 2022-02-14   NaN        NaN       NaN        NaN

# %%
#Calculating the predictions for the next 5 days from current date based on the 2-day SMA
#predictions = df['2-day SMA'].rolling(2).mean()
#df['2-day SMA'].head(15)

X = df['Close'].values
size = np.sum(df['Date'] <= '2021-12-31')
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()

for t in range(len(test)) + 5:
  #Take the first value
  yhat = output[0]
  predictions.append(yhat)
  obs = test[t]
  history.append(obs)
  #history.append(yhat)

# %%
prediction.head(15)

# %%
#Weighted moving average - for 10 days
weights = np.arange(1,11)
weights
wma10 = df['Close'].rolling(10).apply(lambda price: np.dot(price,weights)/weights.sum(), raw = True)
wma10

# %%
np.dot([3,3],[2,5])

# %%
#Exponential moving average
ema10 = df['Close'].ewm(span=10,adjust= False).mean()
ema2 = df['Close'].ewm(span=2,adjust= False).mean()

df['10-day EMA'] = np.round(ema10,decimals=3)
df['2-day EMA'] = np.round(ema2,decimals=3)
train = df.loc[df['Date'] <= '2021-12-31']
test = df.loc[df['Date'] > '2021-12-31']
test = test.set_index('Date')
test.index = pd.to_datetime(test.index)



plt.figure(figsize=(12,6))
plt.plot(test['Close'], label='Price')
plt.plot(test['10-day EMA'],label='10-day EMA')
plt.plot(test['2-day EMA'],label='2-day EMA')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
df.head(10)

# %%
#ARIMA - Proper model which puts the differentiation into prediction
#How will be my model performance for the next 1 day
from statsmodels.tsa.arima_model import ARIMA
X = df['Close'].values
size = np.sum(df['Date'] <= '2021-12-31')
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()

for t in range(len(test)):
  model = ARIMA(history, order=(1,1,0)) #Order p,q,d
  model_fit = model.fit()
  output = model_fit.forecast()
  #Take the first value
  yhat = output[0]
  predictions.append(yhat)
  obs = test[t]
  history.append(obs)
  #history.append(yhat)

test = df.loc[df['Date'] > '2021-12-31']
test = test.set_index('Date')
test.index = pd.to_datetime(test.index)
test.loc[:,'ARIMA'] = predictions



plt.figure(figsize=(12,6))
plt.plot(test['Close'], label='Price')
plt.plot(test['ARIMA'],label='ARIMA')
#plt.plot(test['2-day EMA'],label='2-day EMA')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
#ARIMA - Proper model which puts the differentiation into prediction
#How will be my model performance for the next 1 day
from statsmodels.tsa.arima_model import ARIMA
X = df['Close'].values
size = np.sum(df['Date'] <= '2021-12-31')
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()

for t in range(len(test)):
  model = ARIMA(history, order=(1,2,0)) #Order p,d,q
  #P - AR
  # D - max 2
  # Q - MA (Order)
  model_fit = model.fit()
  output = model_fit.forecast()
  #Take the first value
  yhat = output[0]
  predictions.append(yhat)
  obs = test[t]
  history.append(obs)
  #history.append(yhat)

test = df.loc[df['Date'] > '2021-12-31']
test = test.set_index('Date')
test.index = pd.to_datetime(test.index)
test.loc[:,'ARIMA'] = predictions



plt.figure(figsize=(12,6))
plt.plot(test['Close'], label='Price')
plt.plot(test['ARIMA'],label='ARIMA')
#plt.plot(test['2-day EMA'],label='2-day EMA')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()

# %%
# !pip install
